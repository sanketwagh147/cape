# %%
# !git clone https://github.com/nathanramoscfa/cape.git
# Out:
# Cloning into 'cape'...
# remote: Enumerating objects: 647, done.
# remote: Counting objects: 100% (100/100), done.
# remote: Compressing objects: 100% (86/86), done.
# remote: Total 647 (delta 19), reused 91 (delta 12), pack-reused 547
# Receiving objects: 100% (647/647), 57.04 MiB | 26.02 MiB/s, done.
# Resolving deltas: 100% (45/45), done.

# %%
from cape import cape
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-12-7eaa28360e99> in <module>
# ----> 1 from cape import cape
#
# /content/cape.py in <module>
#       1 import pandas as pd
# ----> 2 from cape import fwd_return_5y_forecast
#       3 from IPython.display import Image
#       4
#       5
#
# ImportError: cannot import name 'fwd_return_5y_forecast' from 'cape' (/content/cape.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
