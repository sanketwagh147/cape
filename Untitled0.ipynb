# %% [markdown]
# # Forecasting Future Long-Run Stock Returns with Robert Shiller's Cyclically Adjusted Price-Earnings Ratio (CAPE)

# %% [markdown]
# To use this notebook, click "Runtime" in the menu above, then choose "Run all" which will run all the code below from top to bottom.

# %%
import requests
r = requests.get('https://raw.githubusercontent.com/nathanramoscfa/cape/main/cape/cape.py')
with open('cape.py', 'w') as f:
  f.write(r.text)
import cape

# %%
cape.print_data_date()
# Out:
# Data current as of: 2022-09-30

# %% [markdown]
# ## Results Ranked by Forward Return 5-Year Forecast

# %% [markdown]
# These ETFs have an expected annualized 5-year return greater than 15%.

# %%
cape.forward_return_forecast(breakpoint_return=0.15, above=True, top=None, drop_duplicates=False)
# Out:
# ETFs with above 0.15% expected forward 5-year return:
#                                                ETF_NAME  \
# TICKER
# PSCD    Invesco S&P SmallCap Consumer Discretionary ETF
# SPSM               SPDR Portfolio S&P 600 Small Cap ETF
# SLY                           SPDR S&P 600 Small CapETF
# VIOO                     Vanguard S&P Small-Cap 600 ETF
# IJR                      iShares Core S&P Small-Cap ETF
# SLYG                  SPDR S&P 600 Small Cap Growth ETF
# IJT                iShares S&P Small-Cap 600 Growth ETF
# VIOG              Vanguard S&P Small-Cap 600 Growth ETF
# IJS                 iShares S&P Small-Cap 600 Value ETF
# SLYV                    SPDR S&P 600 Small CapValue ETF
# VIOV               Vanguard S&P Small-Cap 600 Value ETF
# QLD                                 ProShares Ultra QQQ
# QQQ                          Invesco QQQ Trust Series 1
# TQQQ                             ProShares UltraPro QQQ
#
#                                                INDEX_NAME   CAPE  \
# TICKER
# PSCD    S&P 600 Consumer Discretionary Sector GICS Lev...  11.54
# SPSM                              S&P Small Cap 600 Index  16.15
# SLY                               S&P Small Cap 600 Index  16.15
# VIOO                              S&P Small Cap 600 Index  16.15
# IJR                               S&P Small Cap 600 Index  16.15
# SLYG                       S&P Small Cap 600 Growth Index  22.15
# IJT                        S&P Small Cap 600 Growth Index  22.15
# VIOG                       S&P Small Cap 600 Growth Index  22.15
# IJS                         S&P Small Cap 600 Value Index  13.18
# SLYV                        S&P Small Cap 600 Value Index  13.18
# VIOV                        S&P Small Cap 600 Value Index  13.18
# QLD                                      NASDAQ-100 Index  35.77
# QQQ                                      NASDAQ-100 Index  35.77
# TQQQ                                     NASDAQ-100 Index  35.77
#
#         FWD_RETURN_5Y_FORECAST INDEX_TICKER
# TICKER
# PSCD                    0.2516       S6COND
# SPSM                    0.2039          SML
# SLY                     0.2039          SML
# VIOO                    0.2039          SML
# IJR                     0.2039          SML
# SLYG                    0.2001         SMLG
# IJT                     0.2001         SMLG
# VIOG                    0.2001         SMLG
# IJS                     0.1964         SMLV
# SLYV                    0.1964         SMLV
# VIOV                    0.1964         SMLV
# QLD                     0.1672          NDQ
# QQQ                     0.1672          NDQ
# TQQQ                    0.1672          NDQ

# %% [markdown]
# These ETFs have an expected annualized 5-year return loss.

# %%
cape.forward_return_forecast(breakpoint_return=0.0, above=False, top=None, drop_duplicates=False)
# Out:
# ETFs with below 0.0% expected forward 5-year return:
#                                  ETF_NAME  \
# TICKER
# OIH               VanEck Oil Services ETF
# SPYV     SPDR Portfolio S&P 500 Value ETF
# IVE             iShares S&P 500 Value ETF
# VOOV           Vanguard S&P 500 Value ETF
# IUSV      iShares Core S&P U.S. Value ETF
# XLU     Utilities Select Sector SPDR Fund
# FUTY    Fidelity MSCI Utilities Index ETF
# VPU                Vanguard Utilities ETF
# IDU              iShares US Utilities ETF
#
#                                                INDEX_NAME   CAPE  \
# TICKER
# OIH     Philadelphia Stock Exchange Oil Service Sector...   6.26
# SPYV                                  S&P 500 Value Index  19.26
# IVE                                   S&P 500 Value Index  19.26
# VOOV                                  S&P 500 Value Index  19.26
# IUSV                                  S&P 500 Value Index  19.26
# XLU                              MSCI USA Utilities Index  18.99
# FUTY                             MSCI USA Utilities Index  18.99
# VPU                              MSCI USA Utilities Index  18.99
# IDU                              MSCI USA Utilities Index  18.99
#
#         FWD_RETURN_5Y_FORECAST INDEX_TICKER
# TICKER
# OIH                    -0.2295          OSX
# SPYV                   -0.0035          SVX
# IVE                    -0.0035          SVX
# VOOV                   -0.0035          SVX
# IUSV                   -0.0035          SVX
# XLU                    -0.0021      MXUS0UT
# FUTY                   -0.0021      MXUS0UT
# VPU                    -0.0021      MXUS0UT
# IDU                    -0.0021      MXUS0UT

# %% [markdown]
# ## ETF Single Ticker Results Lookup

# %% [markdown]
# Pull up forecast data on a single ETF ticker.

# %%
cape.available_tickers()
# Out:
# Available ETF tickers:
#
# ACWI BBRE BBUS BKLC BKSE CRBN DIA DVY ESGU ESML
# FAS FDIS FENY FMAT FNCL FRI FSTA FTEC FUTY GSUS
# IDU IJH IJJ IJK IJR IJS IJT ILCB ILCG IMCG
# ITOT IUSV IVE IVOO IVOV IVV IWB IWD IWF IWL
# IWM IWN IWP IWR IWS IWV IXC IXN IYE IYH
# IYW IYY JHML JHMM JHSC JUST KBWB KOKU KRE MDY
# MDYG MDYV MGK NUSC OEF OIH ONEQ OVL PBSM PSCD
# PSCT QLD QQQ RWR SCHA SCHB SCHG SCHK SCHV SCHX
# SLY SLYG SLYV SMH SMMD SNPE SOXL SOXX SPLG SPMD
# SPSM SPXL SPY SPYV SPYX SSO SSPY TECL TMFC TNA
# TOK TQQQ UPRO URTH USRT VAW VB VDC VDE VFH
# VGT VIOG VIOO VIOV VO VONE VONG VONV VOO VOOV
# VOT VPU VTI VTWO VTWV VUG VV XHB XLB XLE
# XLF XLG XLI XLK XLU XLV XME XOUT

# %% [markdown]
# ## Results for ETF

# %%
etf_ticker = 'PSCD'

# %%
cape.ticker_results(etf_ticker)
# Out:
# ETF_NAME                    Invesco S&P SmallCap Consumer Discretionary ETF
# INDEX_NAME                S&P 600 Consumer Discretionary Sector GICS Lev...
# CAPE                                                                  11.54
# FWD_RETURN_5Y_FORECAST                                               0.2516
# INDEX_TICKER                                                         S6COND
# Name: PSCD, dtype: object
# Expected 5-Year Return (S&P 600 Consumer Discretionary Sector GICS Level 1 Index): 25.16%

# %%
cape.chart(etf_ticker, chart_num=2)
