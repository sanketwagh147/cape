# %%
# !git clone https://github.com/nathanramoscfa/cape.git

# %%
# !pip install git+https://github.com/nathanramoscfa/cape.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/nathanramoscfa/cape.git
#   Cloning https://github.com/nathanramoscfa/cape.git to /tmp/pip-req-build-frtrpvjy
#   Running command git clone -q https://github.com/nathanramoscfa/cape.git /tmp/pip-req-build-frtrpvjy
# WARNING: Discarding git+https://github.com/nathanramoscfa/cape.git. Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
# ERROR: Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.

# %%
cape.import_results()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e299e1b4dde1> in <module>
# ----> 1 cape.import_results()
#
# NameError: name 'cape' is not defined
