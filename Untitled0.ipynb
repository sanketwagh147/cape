# %%
# !git clone https://github.com/nathanramoscfa/cape.git
# Out:
# Cloning into 'cape'...
# remote: Enumerating objects: 669, done.
# remote: Counting objects: 100% (122/122), done.
# remote: Compressing objects: 100% (103/103), done.
# remote: Total 669 (delta 32), reused 104 (delta 16), pack-reused 547
# Receiving objects: 100% (669/669), 57.05 MiB | 21.74 MiB/s, done.
# Resolving deltas: 100% (58/58), done.

# %%
# !pip install git+https://github.com/nathanramoscfa/cape.git

# %%
from cape import cape
# Out:
# Data current as of: 2022-09-30

# %%
cape.cape.import_results()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-3ad1f640e13e> in <module>
# ----> 1 cape.cape.import_results()
#
# AttributeError: module 'cape.cape' has no attribute 'cape'
