# %%
# !git clone https://github.com/nathanramoscfa/cape.git
# Out:
# fatal: destination path 'cape' already exists and is not an empty directory.

# %%
# !pip install git+https://github.com/nathanramoscfa/cape.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/nathanramoscfa/cape.git
#   Cloning https://github.com/nathanramoscfa/cape.git to /tmp/pip-req-build-ln340_f6
#   Running command git clone -q https://github.com/nathanramoscfa/cape.git /tmp/pip-req-build-ln340_f6
# ERROR: File "setup.py" not found for legacy project git+https://github.com/nathanramoscfa/cape.git.

# %%
cape.import_results()
