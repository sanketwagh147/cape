# %%
# !git clone https://github.com/nathanramoscfa/cape.git

# %%
# !pip install git+https://github.com/nathanramoscfa/cape.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/nathanramoscfa/cape.git to /tmp/pip-req-build-huhbssu8
#   Running command git clone -q https://github.com/nathanramoscfa/cape.git /tmp/pip-req-build-huhbssu8
# ...
#      |████████████████████████████████| 1.6 MB 2.1 MB/s
# ...
#   Created wheel for cape: filename=cape-0.0.0-py3-none-any.whl size=3468 sha256=2750d81acff770d7c54aff71c64d56c3ce7bf38c7c560f861a9310c618c1715e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-8asiwz_u/wheels/12/a6/e1/81b34d3cb8e504ab49cce7dfbd69296f853f2c1030ef33f9d8
# Successfully built cape
# ...

# %%
import cape
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-28337343ed32> in <module>
# ----> 1 import cape
#
# ModuleNotFoundError: No module named 'cape'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
cape.import_results()
